# %% [markdown]
# <a href="https://colab.research.google.com/github/prayashpaudel174-web/portfolio-prayash/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i
#2. Initialize an all one array with size 4X2.
arr2= np.ones((4,2))
print(arr2)


#3. Return a new array of given shape and type, filled with fill value.{Hint: np.full}
arr3 = np.full((3, 3), 7)
print(arr3)


#4. Return a new array of zeros with same shape and type as a given array.{Hint: np.zeros like}
a = np.array([[1, 2], [3, 4]])
arr4 = np.zeros_like(a)
prinmport numpy as np
#1. Initialize an empty array with size 2X2.
arr1= np.empty((2,2))
print(arr1.shape)

t(arr4)


#5. Return a new array of ones with same shape and type as a given array.{Hint: np.ones like}
a1 = np.array([[1, 2], [3, 4]])   # given array
arr5 = np.ones_like(a1)
print(arr5)


#6. For an existing list new_list = [1,2,3,4] convert to an numpy array.{Hint: np.array()}
new_list = [1, 2, 3, 4]
arr6 = np.array(new_list)
print(arr6)
# Out:
#   File "/tmp/ipython-input-3726974852.py", line 15
#     prinmport numpy as np
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # New section
